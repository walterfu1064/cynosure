# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as pyplot

# %%
from src.beam_propagation.beam_propagator import BeamPropagator, PlaneConfig, OpticalConfig

# %%
bp = BeamPropagator(
    PlaneConfig(128, 0.1),
    PlaneConfig(128, 0.05),
    OpticalConfig(0.8, 10.0e3, 0.8),
    3
)

# %%
pyplot.imshow(bp.zernike_bank[6].numpy())

# %%
bp.zernike_bank.shape
# Out:
# torch.Size([10, 128, 128])

# %%
bp.czt
# Out:
# ChirpZTransform2D(
#   (czt_last): ChirpZTransform1D()
#   (czt_penult): ChirpZTransform1D()
# )
